# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("/home/rjoker/DeepLearning/face_image.jpeg")

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (341, 148, 3)

# %%
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %% [markdown]
# # Method #1: Grayscale Pixel Values as Features

# %%
img2 = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img2)

# %%
gray = cv2.cvtColor(img2,cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(gray)

# %%
gray.shape
# Out:
# (341, 148)

# %%
import numpy as np

# %%
features = np.reshape(gray,(341*148))

# %%
features.shape
# Out:
# (50468,)

# %%
features
# Out:
# array([255, 255, 255, ..., 255, 255, 255], dtype=uint8)

# %% [markdown]
# # Method #2: Mean Pixel Value of Channels

# %%
feature_matrix = np.zeros((341,148)) 
feature_matrix.shape
# Out:
# (341, 148)

# %%
for i in range(0,img2.shape[0]):
    for j in range(0,img2.shape[1]):
        feature_matrix[i][j] = ((int(img2[i,j,0]) + int(img2[i,j,1]) + int(img2[i,j,2]))/3)

# %%
features2 = np.reshape(feature_matrix, (341*148)) 
features2.shape
# Out:
# (50468,)

# %% [markdown]
# # Method #3: Extracting Edge Features

# %%
blur = cv2.GaussianBlur(img,(5,5),10)
plt.imshow(blur)

# %%
canny = cv2.Canny(blur,50,100)

# %%
plt.imshow(canny)
